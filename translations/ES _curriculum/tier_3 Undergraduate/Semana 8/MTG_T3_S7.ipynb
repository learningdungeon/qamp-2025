# %% [markdown]
# # GUÍA DEL DOCENTE PRINCIPAL
# ## Título de la Unidad: Cifrado Cuántico (BB84) (Semana 8)
#
# Este módulo sirve como la síntesis final del currículo de Nivel 3. Aplica los principios de Superposición (Semana 1), Bases de Medición (Semana 2) y Ruido/Perturbación (Semana 5) para resolver un problema criptográfico real. Demuestra que la mecánica cuántica proporciona seguridad incondicional a través de las leyes de la física.
#
# ---
#
# ### Información General
#
# | Campo                | Detalle                                                                 |
# |----------------------|-------------------------------------------------------------------------|
# | Público objetivo     | Nivel 3 – Licenciatura / Desarrolladores                                |
# | Principio de diseño  | Seguridad basada en la teoría de la información. Los conceptos requieren simular toda la tubería de QKD: Transmisión → Sifting → Estimación de errores → Reconciliación → Amplificación de privacidad. |
# | Progresión de aprendizaje | Protocolo BB84 (Bases) → Teorema de No-Clonación (Prueba de seguridad) → Sifting y QBER → Post-procesamiento clásico. |
# | Duración             | 1 semana (aprox. 4 sesiones de 60-90 minutos)                           |
# | Guía para docentes   | Es esencial dominar teoría de la probabilidad (probabilidades condicionales). Enfatizar que el "cifrado" no es la parte cuántica; la **distribución de claves** sí lo es. El enlace cuántico solo genera el secreto compartido. |
#
# ---
#
# ## 2. Marco Pedagógico: El Motor de Seguridad
#
# Esta unidad utiliza la **Medición Cuántica** para crear seguridad y **Algoritmos Clásicos** para destilarla. El objetivo es pasar de "circuitos cuánticos" a "protocolos cuánticos".
#
# | Área de enfoque      | Objetivo (El estudiante será capaz de...)                               | Nivel de Bloom        |
# |----------------------|------------------------------------------------------------------------|----------------------|
# | Ciencia/Literacidad  | Explicar por qué el **Teorema de No-Clonación** impide que Eve copie la clave y cómo la **perturbación por medición** revela su presencia (25% de tasa de error). | Comprender, Analizar |
# | Matemáticas          | Calcular el **Quantum Bit Error Rate (QBER)** esperado para un ataque de interceptar y reenviar. Calcular la fórmula final de la tasa de clave segura 𝑅 ≈ 1 − 𝐻₁(𝑒) − 𝐻₂(𝑒). | Aplicar, Evaluar     |
# | Lógica computacional | Implementar la simulación completa de BB84 en Python/Qiskit, incluyendo el "Sifting" clásico y la "Reconciliación de errores" (lógica tipo Cascade). | Aplicar, Crear       |
#
# ---
#
# ## 3. Refinamientos de Lógica Computacional (Semana 8)
#
# ### A. El Protocolo: Bases Conjugadas
#
# | Concepto         | Explicación                                              |
# |------------------|---------------------------------------------------------|
# | Rectilínea (𝒁)   | La base computacional estándar. Usada para los bits 0 y 1. |
# | Diagonal (𝑿)     | La base de superposición. Creada por compuertas Hadamard. |
# | Imparcialidad    | Medir un estado Z en la base X (o viceversa) da un resultado aleatorio. Esta es la característica central de seguridad. |
#
# ### B. Seguridad: Perturbación Detectable
#
# | Concepto         | Explicación                                              | Descripción matemática      |
# |------------------|---------------------------------------------------------|----------------------------|
# | Dilema de Eve    | Eve debe medir para conocer la clave, pero medir en la base incorrecta destruye el estado. | 𝑃(Eve base incorrecta) = 0.5 |
# | QBER             | Tasa de error introducida por Eve. Si ataca todos los bits, induce un 25% de error en la clave cribada. | 𝑄𝐵𝐸𝑅 = 0.5 × 0.5 = 25%      |
#
# ### C. Post-procesamiento: Destilando el Secreto
#
# | Concepto         | Explicación                                              | Descripción matemática      |
# |------------------|---------------------------------------------------------|----------------------------|
# | Sifting          | Descartar bits donde Alice y Bob usaron bases diferentes. | if basis_A == basis_B: keep |
# | Reconciliación   | Corregir errores usando comprobaciones de paridad (ej. protocolo Cascade). Filtra algo de información a Eve. | Búsqueda binaria de errores. |
# | Amplificación de privacidad | Reducir la clave para eliminar el conocimiento parcial de Eve. | 𝐾_final = Hash(𝐾_corregida) |
#
# ---
#
# ## 4. Plan de Clase Ejemplar: El Código Inquebrantable
#
# **Módulo: Simulación de QKD**
# Esta lección se centra en la implementación por software del protocolo, simulando las acciones de Alice, Bob y Eve.
#
# ### Laboratorio de Código: Simulación BB84 (Tier3W8coding.ipynb)
#
# #### Objetivo
# El estudiante escribirá un programa en Python que simule la transmisión de qubits, la interceptación por Eve y los pasos clásicos de post-procesamiento para derivar una clave secreta compartida.
#
# #### Recursos requeridos
# - Entorno Python (Jupyter)
# - Tier3W8coding.ipynb
# - Tier3W8draft.ipynb (Notas de clase)
#
# #### Instrucciones paso a paso
#
# **Parte 1: Matemáticas (Notas de clase)**
# 1. Árbol de probabilidad: Dibuja el árbol para un bit interceptado. Alice envía |0⟩ → Eve mide en X (|+⟩) → Bob mide en Z (0 o 1). Muestra la ruta del 25% de error.
# 2. Coincidencia de bases: Demuestra matemáticamente por qué el sifting es necesario (el 50% de los datos crudos es ruido).
#
# **Parte 2: Código (Implementación en Qiskit)**
# 1. Tarea 1 (Alice): Generar cadenas aleatorias de bits para datos y bases. Codificar en circuitos (I, X, H, XH).
# 2. Tarea 2 (Transmisión):
#    - Sin Eve: Bob mide usando bases aleatorias. Implementar **Sifting**: raw_key = [b for a, b, m in zip(a_bases, b_bases, results) if a==b].
#    - Con Eve: Eve mide (bases aleatorias) y vuelve a codificar. Bob mide los qubits de Eve.
# 3. Tarea 3 (Análisis): Calcular el **QBER** comparando las claves cribadas de Alice y Bob. Si 𝑄𝐵𝐸𝑅 ≈ 0, la clave es segura. Si 𝑄𝐵𝐸𝑅 ≈ 25%, descartar la clave.
# 4. Tarea 4 (Privacidad): Implementar un hash XOR simple para reducir la longitud de la clave y amplificar la privacidad.
#
# **Parte 3: Evaluación**
# - Pregunta 3: ¿Qué pasa si Bob mide |0⟩ en la base X? (Respuesta: Aleatorio 0 o 1).
# - Pregunta 7: ¿Cuál es el QBER teórico si Eve intercepta cada bit? (Respuesta: 25%).
# - Pregunta 9: ¿Qué paso elimina la información parcial de Eve? (Respuesta: Amplificación de privacidad).
#
# ---
#
# ## 5. Recursos para la Implementación Curricular (Semana 8)
#
# | Nombre del recurso      | Tipo                  | Propósito en el currículo                                                                 |
# |------------------------|-----------------------|-------------------------------------------------------------------------------------------|
# | Tier3W8draft           | Notas de clase (IPYNB)| Derivación formal de los estados BB84, probabilidades de ataque interceptar-reenviar y el flujo de post-procesamiento. |
# | Tier3W8coding          | Cuaderno de laboratorio (IPYNB) | Tareas de codificación para simular el protocolo multiagente completo (Alice, Bob, Eve).   |
# | TierW8                 | Quiz (IPYNB)          | Chequeo de conocimientos: 10 preguntas de opción múltiple sobre la física de QKD y la lógica de la prueba de seguridad. |
#
# ---
#
# ## 6. Conclusión y Siguientes Pasos
#
# Este módulo de **Nivel 3, Semana 8** concluye el currículo de Nivel 3. Los estudiantes han recorrido desde el álgebra lineal básica de un solo qubit hasta la implementación de protocolos de comunicación cuántica segura.
#
# **Punto clave:** La seguridad cuántica depende de las **leyes de la física** (No-Clonación, Principio de Incertidumbre), no de la dificultad computacional.
#
# **Revisión final:** Los estudiantes ahora están preparados para avanzar a **Nivel 4 (Avanzado)**, donde explorarán Corrección de Errores Cuánticos y otros algoritmos más avanzados como el Algoritmo de Shor.
