# %% [markdown]
# # Guía Maestra del Docente
# ## Título de la Unidad: El Secreto Inquebrantable (Teorema Cuántico de No-Clonación)
#
# Este currículo está diseñado para una introducción de 4 semanas, basada en proyectos, sobre la limitación fundamental de la información cuántica usando IBM Quantum Composer (herramienta visual sin código) y conceptos de Qiskit.
#
# ---
#
# ### 1. Panorama del Currículo
#
# | Campo                  | Detalle                                                                                      |
# |------------------------|----------------------------------------------------------------------------------------------|
# | **Público objetivo**   | Nivel 4 – Avanzado                                                                          |
# | **Principio de diseño**| Alineación transversal: conceptos alineados con Matemáticas (Probabilidad), Ciencia (Leyes Fundamentales) y Computación (Lógica/Secuenciación). |
# | **Progresión de aprendizaje** | Precarga conceptual (Narrativa) → Modelado aplicado (IBM Composer) → Comprensión conceptual (Transferencia vs. Copia) |
# | **Duración**           | 4 semanas (aprox. 4 sesiones de 45-60 minutos cada una)                                     |
# | **Guía docente**       | La semana 1 se enfoca en conceptos y alfabetización. El trabajo visual con Quantum Composer inicia en la semana 2, centrado en el fallo de la compuerta CNOT para copiar estados en superposición. |
#
# ---
#
# ### 2. Marco Pedagógico: La Bóveda Cuántica
#
# | Área de enfoque        | Objetivo (El estudiante será capaz de...)                                                    | Nivel de Bloom           |
# |------------------------|----------------------------------------------------------------------------------------------|--------------------------|
# | Ciencia/Alfabetización | Definir el Teorema de No-Clonación como una ley fundamental que prohíbe crear una copia idéntica e independiente de un estado desconocido. | Analizar, Comprender     |
# | Matemáticas            | Entender que la clonación solo funciona para estados clásicos (100% de probabilidad de 0 o 1), pero falla para estados de superposición. | Aplicar                  |
# | Computacional          | Demostrar el fallo de la compuerta CNOT al intentar clonar una superposición, resultando en un **enlace entrelazado** no separable. | Crear, Analizar          |
#
# ---
#
# ### 3. Secuencia Curricular Nivel 4 (4 Semanas)
#
# | Módulo                  | Semana   | Actividad central                                   | Concepto cuántico clave                                    |
# |-------------------------|----------|-----------------------------------------------------|------------------------------------------------------------|
# | 1. Alfabetización básica| Semana 1 | Hojas de comprensión ("El Pergamino Mágico / La Impresora Rota") | Evolución unitaria (reversibilidad), necesidad de estado desconocido arbitrario |
# | 2. Laboratorio aplicado 1| Semana 2 | Éxito del copiador CNOT (Laboratorio Composer)      | Confirmación de que CNOT ("Enlace en tándem") puede copiar estados clásicos     |
# | 3. Laboratorio aplicado 2| Semana 3 | Fallo de la clonación CNOT (Laboratorio Composer)   | Demostración del Teorema de No-Clonación. CNOT sobre superposición crea **entrelazamiento** (estado de Bell) en vez de dos copias independientes |
# | 4. Proyecto final de lógica| Semana 4 | Protocolo de transferencia de estado (Modelo conceptual de teleportación en Qiskit) | Resultado del No-Clonación: La información debe **transferirse** (moverse destructivamente), no **copiarse** |
#
# ---
#
# ### 4. Unidades de Alfabetización Básica (Semana 1)
#
# #### Unidad A: El Pergamino Mágico del Estado Desconocido (Narrativa)
#
# | Metáfora central        | Concepto cuántico           | Idea clave para el estudiante                  |
# |-------------------------|-----------------------------|-----------------------------------------------|
# | El hechizo desconocido  | Estado arbitrario desconocido| $\psi$                                        |
# | El hechizo de duplicación perfecta | Clonador unitario universal | Una acción simple (compuerta) que funciona siempre, sin importar el hechizo en el pergamino |
# | La ley del imitador     | Teorema de No-Clonación     | Este hechizo de duplicación perfecta **no puede existir** para el hechizo desconocido |
#
# #### Unidad B: La Impresora Rota (Ciencia/Comprensión)
#
# | Concepto central        | Metáfora/Analogía           | Área clave de evaluación                      |
# |-------------------------|-----------------------------|-----------------------------------------------|
# | Estados conocidos (0 o 1)| La página negra o blanca    | Copiar una página completamente negra es fácil (CNOT funciona) |
# | Estados de superposición| La página gris (mezcla de negro y blanco) | La impresora cuántica (CNOT) intenta copiar la página gris pero une las dos páginas de salida permanentemente (entrelazamiento) |
# | Información oculta      | Colapso al medir            | Si medimos la "página gris", destruimos el tono específico y la información oculta se pierde para siempre |
#
# ---
#
# ### 5. Refinamientos de Lógica Computacional (Semanas 2-4)
#
# #### A. Lógica y Geometría Nivel 4 (Semanas 2-3)
#
# | Compuerta clave         | Modelo conceptual (Nivel 4)   | Acción clave de CNOT y modo de fallo           |
# |-------------------------|------------------------------|------------------------------------------------|
# | X/H Gates               | Giro/mezcla del compás cuántico| La compuerta H crea el **estado desconocido** (la mezcla) |
# | RX, RY Dials            | "Enlace en tándem" (cable de conexión) | Al aplicarse a una mezcla, CNOT falla en producir dos mezclas separadas. Produce un solo sistema inseparable (**entrelazamiento**) |
#
# #### B. Introducción a la Transferencia (Semana 4: Protocolo de Transferencia de Estado)
#
# | Concepto Nivel 4        | Descripción                  | Conexión con No-Clonación                      |
# |-------------------------|------------------------------|------------------------------------------------|
# | Lógica de protocolo     | Alice y Bob deben compartir un **enlace entrelazado** (creado por H + CNOT) | Si existiera la clonación, este enlace complejo sería innecesario |
# | Acción clave: Medición  | Alice mide sus qubits, **destruyendo** instantáneamente el estado secreto original | El estado se consume en el origen; es una **transferencia**, no una **copia** |
# | Requisito de bits clásicos | Alice debe enviar dos bits clásicos (00, 01, 10, o 11) a Bob para "arreglar" su qubit | Si fuera clonación, Bob tendría la copia instantáneamente. La necesidad del mensaje clásico significa que el proceso no es instantáneo (evita señalización más rápida que la luz) |
#
# ---
#
# ### 6. Puente conceptual de Nivel 4 a Experto
#
# Esta sección define claramente el cambio de complejidad requerido para el siguiente nivel de experiencia, pasando de la demostración visual a la prueba axiomática.
#
# ---
#
# ### 7. Recursos para la Implementación Curricular
#
# | Nombre del recurso                  | Tipo                  | Propósito en el currículo                      |
# |-------------------------------------|-----------------------|------------------------------------------------|
# | IBM Quantum Composer                | Herramienta visual (Web) | Plataforma central para todos los laboratorios. Los estudiantes usan la interfaz de arrastrar y soltar para intentar construir un circuito de clonación universal usando compuertas disponibles (Hadamard, CNOT, Toffoli, etc.) |
# | Visualización de la esfera de Bloch (en Composer) | Herramienta visual (Gráfica) | Permite visualizar el estado inicial del qubit de entrada ($\psi$) y el estado resultante de los dos qubits de salida, demostrando visualmente la **corrupción del estado** en vez de clonación perfecta |
# | Hojas de trabajo Nivel 4: Intentos de clonación | Documentación (PDF/MD) | Ejercicios para guiar la construcción de varios circuitos de "clonación" y registrar las **probabilidades de medición** para cada qubit de salida, resaltando cuando no se logra el resultado ideal |
# | Qiskit Textbook: Compuertas cuánticas | Referencia (Web)      | Revisión de la **linealidad y reversibilidad de las compuertas**, explicando por qué una unidad de clonación exitosa violaría estos principios fundamentales |
# | Plan de lección ejemplar: No-Clonación vía CNOT | Documentación (PDF)   | Instrucciones paso a paso para demostrar el fallo de la compuerta CNOT al intentar clonar universalmente, base para la seguridad de **BB84 (Criptografía cuántica)** |
#
# ---
#
# ### Plan de lección ejemplar: Visualizando el fallo de la clonación
#
# **Módulo:** Información cuántica y criptografía
# Esta lección se centra en la observación empírica dentro de **IBM Quantum Composer** para confirmar la limitación fundamental de la mecánica cuántica.
#
# #### 🧪 Laboratorio Composer: Intentando el Clon Cuántico Universal
#
# | Elemento                | Detalle                                                         |
# |-------------------------|------------------------------------------------------------------|
# | **Objetivo**            | Los estudiantes intentarán construir un circuito cuántico que copie el estado de un **qubit de entrada arbitrario desconocido** (q0) en un qubit nuevo (q1). Usando la visualización de la esfera de Bloch y los resultados de medición, ilustrarán empíricamente el **Teorema de No-Clonación**. |
# | **Recursos requeridos** | IBM Quantum Composer, Hoja de trabajo Nivel 4 (para registrar resultados) |
#
# ##### Instrucciones paso a paso
#
# **Parte 1: El estado de entrada (el qubit "a clonar")**
# 1. **Inicializa el lienzo:** Comienza con dos qubits, q0 (entrada) y q1 (objetivo), ambos en el estado ∣0⟩.
# 2. **Define el estado de prueba (∣ψ⟩):** Prueba el circuito con dos estados específicos:
#    - **Caso A (fácil):** Prepara q0 en el estado ∣+⟩ aplicando una compuerta **Hadamard (H)** a q0.
#    - **Caso B (difícil):** Prepara q0 en un estado arbitrario en el plano XY, por ejemplo, aplicando una compuerta RY (π/2) seguida de una compuerta P(π/2) a q0.
# 3. **Verificación visual:** Usa el visor de la esfera de Bloch para confirmar la ubicación exacta de q0 antes de continuar.
#
# **Parte 2: Intentando la clonación (el fallo de CNOT)**
# 1. **La copia ingenua:** Arrastra y suelta una **compuerta CNOT** en el circuito, usando q0 como control y q1 como objetivo.
# 2. **Ejecuta y observa (Caso A):** Ejecuta el circuito. Cuando la entrada es ∣+⟩, la salida parecerá ∣+⟩∣+⟩. Registra los resultados.
# 3. **Ejecuta y observa (Caso B):** Ejecuta el circuito para el Caso B.
#    - **Esfera de Bloch:** Observa las posiciones finales de q0 y q1.
#    - **Fallo esperado:** Los estudiantes observarán que la operación CNOT ha resultado en un estado entrelazado (estado de Bell), y q1 **no** es una copia perfecta e independiente de q0.
#
# **Parte 3: Por qué falla (generalización y teoría)**
# 1. **Restricción lineal:** El instructor guía a la clase sobre la linealidad de las compuertas cuánticas. Se discute cómo cualquier **operación unitaria** que clone con éxito dos estados ortogonales (como ∣0⟩ y ∣1⟩) fallará al clonar una superposición de esos estados (como ∣+⟩).
# 2. **Conexión con criptografía:** Se concluye discutiendo cómo esta imposibilidad demostrada es el principio fundamental de seguridad detrás de **BB84 (Distribución Cuántica de Claves)**: un espía no puede copiar de manera no destructiva la clave cuántica transmitida.
#
# ---
#
# ### Conclusión y siguientes pasos
#
# Este módulo de Nivel 4 establece una base teórica y empírica crucial para la información cuántica avanzada. Usando la interfaz visual de IBM Quantum Composer, los estudiantes demuestran la imposibilidad de una máquina de clonación universal, probando el **Teorema de No-Clonación** mediante observación y no solo álgebra lineal abstracta.
#
# La siguiente fase se enfocará en la aplicación práctica de este principio, avanzando hacia el **Protocolo BB84** y, fundamentalmente, los protocolos de **Teleportación Cuántica / Codificación Superdensa** (Semana 4), que son las soluciones necesarias ante la limitación de clonación.
#
# ``
