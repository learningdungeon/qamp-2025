# %% [markdown]
# # Assessment 2: Entanglement & Multi-Compass Concepts
#
# ## Objectives
# - Assess understanding of quantum entanglement and multi-compass systems.
# - Validate practical implementation in Qiskit: creating entangled states and working with multiple qubits.

# %% [markdown]
# ## Section 1: Basic Entanglement
# **Conceptual Question:**
# - Explain what quantum entanglement is and why it is fundamental in quantum computing.

# %%
# Create a Bell state using Qiskit
# Visualize the state on the Bloch Sphere
from qiskit import QuantumCircuit
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(2)
# TODO: Apply H and CNOT gates to create entanglement

# %% [markdown]
# ## Section 2: Three Compasses (Multi-Qubit System)
# **Conceptual Question:**
# - Describe the challenges of managing multiple qubits compared to a single qubit system.

# %%
# Create a circuit with 3 qubits and apply rotations
# Visualize the combined state
qc = QuantumCircuit(3)
# TODO: Apply rotations and entanglement operations

# %% [markdown]
# ## Section 3: Measurement and Correlation
# **Conceptual Question:**
# - How do measurements on entangled qubits differ from measurements on independent qubits?

# %%
# Measure the entangled qubits and analyze correlation
from qiskit import Aer, execute
from qiskit.visualization import plot_histogram

# TODO: Implement measurement and plot results

# %% [markdown]
# ## Evaluation Criteria (20 points each)
# - **Completeness**: All cells executed and answers provided.
# - **Correctness**: Functional code and expected results.
# - **Use of Qiskit**: Proper application of libraries and methods.
# - **Visualization**: Clear and correct plots.
# - **Explanation**: Well-written and coherent Markdown.
#
# **Total: 100 points**
