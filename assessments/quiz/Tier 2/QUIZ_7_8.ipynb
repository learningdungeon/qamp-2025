# %% [markdown]
# # Assessment 4: VQE & Quantum Cryptography (BB84)
#
# ## Objectives
# - Assess understanding of Variational Quantum Eigensolver (VQE) and quantum cryptography principles.
# - Validate practical implementation in Qiskit: VQE circuits and BB84 protocol simulation.

# %% [markdown]
# ## Section 1: Compass Balance - VQE
# **Conceptual Question:**
# - What is VQE and why is it important for solving optimization problems in quantum computing?

# %%
# Implement a simple VQE algorithm using Qiskit
# Define a Hamiltonian and use a variational form
from qiskit.algorithms import VQE
from qiskit.circuit.library import TwoLocal
from qiskit.opflow import Z, I

# TODO: Define Hamiltonian and run VQE

# %% [markdown]
# ## Section 2: Multiple Compass - VQE Extension
# **Conceptual Question:**
# - How does increasing the number of qubits affect the complexity of VQE?

# %%
# Extend VQE to multiple qubits and analyze performance
# TODO: Implement multi-qubit VQE

# %% [markdown]
# ## Section 3: Secret Compass - BB84 Protocol
# **Conceptual Question:**
# - Explain the BB84 protocol and its role in quantum key distribution.

# %%
# Simulate BB84 protocol steps: key generation and basis selection
# TODO: Implement BB84 simulation using Qiskit

# %% [markdown]
# ## Evaluation Criteria (20 points each)
# - **Completeness**: All cells executed and answers provided.
# - **Correctness**: Functional code and expected results.
# - **Use of Qiskit**: Proper application of libraries and methods.
# - **Visualization**: Clear and correct plots.
# - **Explanation**: Well-written and coherent Markdown.
#
# **Total: 100 points**
