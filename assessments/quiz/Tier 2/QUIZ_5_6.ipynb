# %% [markdown]
# # Assessment 3: Error Correction & QAOA Fundamentals
#
# ## Objectives
# - Assess understanding of quantum error correction principles and optimization algorithms.
# - Validate practical implementation in Qiskit: error detection, correction, and QAOA circuits.

# %% [markdown]
# ## Section 1: Simple Error Code
# **Conceptual Question:**
# - Why is error correction necessary in quantum computing and what challenges does it address?

# %%
# Implement a simple repetition code for error detection
# Use Qiskit to create a circuit with redundancy
from qiskit import QuantumCircuit

qc = QuantumCircuit(3)
# TODO: Apply encoding for error detection

# %% [markdown]
# ## Section 2: Redundancy as Detection
# **Conceptual Question:**
# - How does redundancy help in detecting errors in quantum states?

# %%
# Simulate an error and detect it using redundancy
# TODO: Introduce an error and verify detection

# %% [markdown]
# ## Section 3: Qubit Correction with Ancilla
# **Conceptual Question:**
# - Explain the role of ancilla qubits in error correction schemes.

# %%
# Implement a simple error correction using ancilla qubits
# TODO: Apply correction logic

# %% [markdown]
# ## Section 4: Cheapest Electron Path - QAOA
# **Conceptual Question:**
# - What is QAOA and how does it approximate solutions for optimization problems?

# %%
# Build a QAOA circuit for a simple optimization problem
from qiskit.algorithms import QAOA
from qiskit import Aer

# TODO: Define cost function and implement QAOA

# %% [markdown]
# ## Evaluation Criteria (20 points each)
# - **Completeness**: All cells executed and answers provided.
# - **Correctness**: Functional code and expected results.
# - **Use of Qiskit**: Proper application of libraries and methods.
# - **Visualization**: Clear and correct plots.
# - **Explanation**: Well-written and coherent Markdown.
#
# **Total: 100 points**
