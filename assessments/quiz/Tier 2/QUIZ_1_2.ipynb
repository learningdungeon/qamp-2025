# %% [markdown]
# # Assessment 1: Compass & Qubit Fundamentals
#
# ## Objectives
# - Assess understanding of basic concepts: compass, magnetic field, rotation, and transition to qubit.
# - Validate practical implementation in Qiskit: measurement, Bloch Sphere, and basic operations.

# %% [markdown]
# ## Section 1: Compass and Magnetic Field
# **Conceptual Question:**
# - Explain how the magnetic field affects the compass orientation and how it relates to electron spin.

# %%
# Complete the code to simulate the magnetic field on a compass
# Use numpy to calculate the force and matplotlib to plot the orientation
import numpy as np
import matplotlib.pyplot as plt

# TODO: Implement simulation

# %% [markdown]
# ## Section 2: Mathematical Model and Rotation
# **Conceptual Question:**
# - Why is the mathematical model important to describe the compass rotation?

# %%
# Implement a function to calculate the rotation phase
# Parameters: angle in radians, angular velocity

def calculate_phase(angle, velocity):
    # TODO: Implement calculation
    pass

# %% [markdown]
# ## Section 3: From Compass to Qubit
# **Conceptual Question:**
# - Describe the conceptual process to map the compass orientation to a qubit state.

# %%
# Create a qubit in state |0> and apply a Ry rotation
# Visualize the result on the Bloch Sphere
from qiskit import QuantumCircuit
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(1)
# TODO: Apply Ry rotation

# %% [markdown]
# ## Section 4: Measurement and Bloch Sphere
# **Conceptual Question:**
# - What does the Bloch Sphere represent and why is it useful for visualizing quantum states?

# %%
# Generate a circuit with one qubit, apply a rotation, and measure the state
# Use Qiskit to display the Bloch Sphere
from qiskit import Aer, execute
from qiskit.visualization import plot_bloch_multivector

# TODO: Implement circuit and measurement

# %% [markdown]
# ## Evaluation Criteria (20 points each)
# - **Completeness**: All cells executed and answers provided.
# - **Correctness**: Functional code and expected results.
# - **Use of Qiskit**: Proper application of libraries and methods.
# - **Visualization**: Clear and correct plots.
# - **Explanation**: Well-written and coherent Markdown.
#
# **Total: 100 points**
